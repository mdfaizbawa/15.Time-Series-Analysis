# %%
#pip install yfinance

# %%
#pip install nsepy
# Out:
# Collecting nsepy
#   Using cached https://files.pythonhosted.org/packages/89/52/2e9f0de0c687ad181f17e0783319d31d66869c410793c5b94dc6cd4b3db2/nsepy-0.8.tar.gz
# Collecting beautifulsoup4
#   Using cached https://files.pythonhosted.org/packages/69/bf/f0f194d3379d3f3347478bd267f754fc68c11cbf2fe302a6ab69447b1417/beautifulsoup4-4.10.0-py3-none-any.whl
# Requirement already satisfied: requests in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (2.27.1)
# Requirement already satisfied: numpy in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (1.17.4)
# Requirement already satisfied: pandas in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (0.25.3)
# Requirement already satisfied: six in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (1.13.0)
# Requirement already satisfied: click in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (7.1.2)
# Requirement already satisfied: lxml in c:\anaconda3\envs\tf\lib\site-packages (from nsepy) (4.5.1)
# Collecting soupsieve>1.2
#   Using cached https://files.pythonhosted.org/packages/72/a6/fd01694427f1c3fcadfdc5f1de901b813b9ac756f0806ef470cfed1de281/soupsieve-2.3.1-py3-none-any.whl
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\anaconda3\envs\tf\lib\site-packages (from requests->nsepy) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\tf\lib\site-packages (from requests->nsepy) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ramisha krishnasamy\appdata\roaming\python\python37\site-packages (from requests->nsepy) (1.25.7)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\ramisha krishnasamy\appdata\roaming\python\python37\site-packages (from requests->nsepy) (2.8)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda3\envs\tf\lib\site-packages (from pandas->nsepy) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\anaconda3\envs\tf\lib\site-packages (from pandas->nsepy) (2.8.1)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py): started
#   Building wheel for nsepy (setup.py): finished with status 'done'
#   Created wheel for nsepy: filename=nsepy-0.8-cp37-none-any.whl size=36089 sha256=95078d4039402492920a34a337edde65ea2caa0df37092c06af594c57679e44a
#   Stored in directory: C:\Users\Ramisha Krishnasamy\AppData\Local\pip\Cache\wheels\05\2c\72\5324e267426eea65dec0c21a12a48b15887c0cf686c7a8fe11
# Successfully built nsepy
# Installing collected packages: soupsieve, beautifulsoup4, nsepy
# Successfully installed beautifulsoup4-4.10.0 nsepy-0.8 soupsieve-2.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
from nsepy import get_history as gh
import datetime as dt
start = dt.datetime(2021,6,1)
end = dt.datetime(2022,1,5)
stk_data = gh(symbol='TATACOFFEE',start=start,end=end)

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 2021-06-01 to 2022-01-05
# Data columns (total 14 columns):
# Symbol                151 non-null object
# Series                151 non-null object
# Prev Close            151 non-null float64
# Open                  151 non-null float64
# High                  151 non-null float64
# Low                   151 non-null float64
# Last                  151 non-null float64
# Close                 151 non-null float64
# VWAP                  151 non-null float64
# Volume                151 non-null int64
# Turnover              151 non-null float64
# Trades                151 non-null int64
# Deliverable Volume    151 non-null int64
# %Deliverble           151 non-null float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 17.7+ KB

# %%
stk_data
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2021-06-01  TATACOFFEE     EQ      179.20  180.00  181.35  172.65  174.65
# 2021-06-02  TATACOFFEE     EQ      174.25  173.55  175.65  172.05  174.50
# 2021-06-03  TATACOFFEE     EQ      174.00  176.90  178.70  175.60  177.00
# 2021-06-04  TATACOFFEE     EQ      176.70  177.90  177.90  173.75  174.95
# 2021-06-07  TATACOFFEE     EQ      174.35  176.40  176.65  173.00  174.65
# ...                ...    ...         ...     ...     ...     ...     ...
# 2021-12-30  TATACOFFEE     EQ      211.35  211.45  211.50  207.90  208.80
# 2021-12-31  TATACOFFEE     EQ      208.50  208.90  216.20  208.40  213.70
# 2022-01-03  TATACOFFEE     EQ      213.15  213.95  216.90  212.30  214.30
# 2022-01-04  TATACOFFEE     EQ      214.05  214.90  220.80  212.45  217.40
# 2022-01-05  TATACOFFEE     EQ      217.80  218.50  218.70  214.30  214.65
#
#              Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2021-06-01  174.25  175.63  2952622  5.185751e+13   25746              886336
# 2021-06-02  174.00  173.99  2097000  3.648610e+13   16918              485984
# 2021-06-03  176.70  177.22  2329087  4.127615e+13   17875              538287
# 2021-06-04  174.35  175.06  1339871  2.345617e+13   11456              476714
# 2021-06-07  174.35  174.85  1705257  2.981616e+13   14497              599470
# ...            ...     ...      ...           ...     ...                 ...
# 2021-12-30  208.50  209.36   977484  2.046476e+13   10540              272840
# 2021-12-31  213.15  213.37  3045699  6.498541e+13   25219              619788
# 2022-01-03  214.05  214.76  1525259  3.275665e+13   15005              389236
# 2022-01-04  217.80  217.41  3477443  7.560380e+13   28871              823218
# 2022-01-05  214.85  215.72  1350483  2.913257e+13   12079              434596
#
#             %Deliverble
# Date
# 2021-06-01       0.3002
# 2021-06-02       0.2318
# 2021-06-03       0.2311
# 2021-06-04       0.3558
# 2021-06-07       0.3515
# ...                 ...
# 2021-12-30       0.2791
# 2021-12-31       0.2035
# 2022-01-03       0.2552
# 2022-01-04       0.2367
# 2022-01-05       0.3218
#
# [151 rows x 14 columns]

# %%
low=stk_data["Low"]

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume', '%Deliverble']
# The Qualtitative Data ['Symbol', 'Series']

# %%
des_data=obj.descriptive_Analysis(dataset,quan)

# %%
des_data
# Out:
#               Prev Close     Open     High      Low     Last    Close  \
# Null_count             0        0        0        0        0        0
# NonNull_count        151      151      151      151      151      151
# Total_Count          151      151      151      151      151      151
# Mean             203.824  204.718  208.365  200.769  204.159   204.06
# Median             206.1    207.1   210.35    203.8    206.5   206.55
# Mode              174.35      213    178.7      196      213   174.35
# Std              14.8688  15.1548  15.7716  14.5927  14.8002  14.7578
# Min                172.9   170.05   175.65      168    172.5    172.9
# Q1:25%            192.65  193.525    198.1    189.9  193.775    193.7
# Q2:50%             206.1    207.1   210.35    203.8    206.5   206.55
# Q3:75%            213.15  213.925  218.125   210.35    213.4  213.325
# Q4:100%            235.8      241    254.4   231.25   237.75    235.8
# IQR                 20.5     20.4   20.025    20.45   19.625   19.625
# 1.5Rule            30.75     30.6  30.0375   30.675  29.4375  29.4375
# Lesser             161.9  162.925  168.062  159.225  164.338  164.262
# Greater            243.9  244.525  248.163  241.025  242.838  242.762
#
#                   VWAP       Volume     Turnover   Trades Deliverable Volume  \
# Null_count           0            0            0        0                  0
# NonNull_count      151          151          151      151                151
# Total_Count        151          151          151      151                151
# Mean            204.65  3.40297e+06  7.14438e+13  31535.5             724953
# Median          206.33  1.96690e+06  3.97165e+13    20533             488684
# Mode            204.48       516071  1.11184e+13     7542             144755
# Std            15.0952  4.46004e+06  1.00604e+14  36209.8             694324
# Min             172.48       516071  1.11184e+13     7542             144755
# Q1:25%         193.595  1.33142e+06  2.65228e+13  14005.5             336951
# Q2:50%          206.33  1.96690e+06  3.97165e+13    20533             488684
# Q3:75%         213.945  3.32343e+06  6.71641e+13  32089.5             754415
# Q4:100%         246.57   3.5578e+07  8.23445e+14   289204        4.52338e+06
# IQR              20.35  1.99201e+06  4.06413e+13    18084             417464
# 1.5Rule         30.525  2.98802e+06  6.09619e+13    27126             626196
# Lesser          163.07  -1.6566e+06 -3.44392e+13 -13120.5            -289245
# Greater         244.47  6.31144e+06  1.28126e+14  59215.5        1.38061e+06
#
#               %Deliverble
# Null_count              0
# NonNull_count         151
# Total_Count           151
# Mean             0.249152
# Median             0.2465
# Mode               0.2162
# Std             0.0601825
# Min                0.1239
# Q1:25%            0.20325
# Q2:50%             0.2465
# Q3:75%            0.28015
# Q4:100%            0.4608
# IQR                0.0769
# 1.5Rule           0.11535
# Lesser             0.0879
# Greater            0.3955

# %%
des_data["Low"]
# Out:
# Null_count             0
# NonNull_count        116
# Total_Count          116
# Mean              28.906
# Median            28.025
# Mode                26.5
# Std              2.99258
# Min                23.85
# Q1:25%           26.8875
# Q2:50%            28.025
# Q3:75%              30.1
# Q4:100%            38.25
# IQR               3.2125
# 1.5Rule          4.81875
# Lesser           22.0687
# Greater          34.9188
# Name: Low, dtype: object

# %%
des_data["High"]
# Out:
# Null_count             0
# NonNull_count        116
# Total_Count          116
# Mean             30.4987
# Median            29.275
# Mode                27.5
# Std              3.43377
# Min                 25.8
# Q1:25%           27.9375
# Q2:50%            29.275
# Q3:75%           32.4125
# Q4:100%             39.8
# IQR                4.475
# 1.5Rule           6.7125
# Lesser            21.225
# Greater           39.125
# Name: High, dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset["Low"],99)
# Out:
# 229.925

# %%
np.percentile(dataset["High"],80)
# Out:
# 32.8

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["Low"],219,230)
# Out:
# Mean=200.769, Standard Deviation=14.593
# The area between range(219,230):0.08765971141467226
# C:\Anaconda3\envs\ML\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.08765971141467226

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["Low"])

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable("Low",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           196.00          3      1.986755    1.986755
# 1           203.05          2      1.324503    3.311258
# 2           207.15          2      1.324503    4.635762
# 3           186.30          2      1.324503    5.960265
# 4           210.20          2      1.324503    7.284768
# ..             ...        ...           ...         ...
# 133         199.35          1      0.662252   97.350993
# 134         208.30          1      0.662252   98.013245
# 135         202.05          1      0.662252   98.675497
# 136         175.60          1      0.662252   99.337748
# 137         173.75          1      0.662252  100.000000
#
# [138 rows x 4 columns]

# %%
freqTable("High",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           178.70          2      1.324503    1.324503
# 1           207.80          2      1.324503    2.649007
# 2           214.70          2      1.324503    3.973510
# 3           209.50          2      1.324503    5.298013
# 4           206.00          2      1.324503    6.622517
# ..             ...        ...           ...         ...
# 135         219.25          1      0.662252   97.350993
# 136         216.70          1      0.662252   98.013245
# 137         218.25          1      0.662252   98.675497
# 138         218.40          1      0.662252   99.337748
# 139         190.00          1      0.662252  100.000000
#
# [140 rows x 4 columns]

# %%
fh=freqTable("High",dataset)

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           193.95          2      1.315789    1.315789
# 6           207.80          2      1.315789    9.210526
# 1           209.50          2      1.315789    2.631579
# 10          214.70          2      1.315789   14.473684
# 8           218.70          2      1.315789   11.842105
# ..             ...        ...           ...         ...
# 47          202.00          1      0.657895   38.815789
# 46          192.50          1      0.657895   38.157895
# 45          187.50          1      0.657895   37.500000
# 44          186.50          1      0.657895   36.842105
# 140         190.00          1      0.657895  100.000000
#
# [141 rows x 4 columns]

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 8     218.70
# 3     218.30
# 10    214.70
# 7     213.00
# 1     209.50
# 6     207.80
# 9     206.00
# 2     204.05
# 0     193.95
# 4     189.00
# 5     178.70
# Name: Unique_Values, dtype: float64
